# %% [markdown]
# ---
# # 파이썬 입문 : 도전! 45가지 기초 문법 실습하기 🙋🏻‍♂️
# ---

# %% [markdown]
# ### 꼭 기억하세요 😊
# + **시간이 다소 소요되더라도** 스스로 생각해서 프로그래밍을 해야**`실력이 향상 됩니다.`**
# + 다양한 문제를 통해서 **`문제 해결`**능력을 향상 시켜봐요.
# + 여러 방식으로 **`같은 결과 값`**이 나오도록 프로그래밍 해보세요.
# + **문제 해결**에 너무 시간이 오래 걸리면 **`검색(구글링 등)`**을 통해서 해결해보세요.
# + **`온라인 Python IDE :`** https://www.programiz.com/python-programming/online-compiler/

# %% [markdown]
# ***
# ## 6. Sequence Item Selection💻
# ***
# #### **`연습예제`** 💻

# %% [markdown]
# `아래 리스트(List)에서` **`apple, kiwi`** `를 추출해서` **`대문자`** `리스트로 출력하세요.` **`가능한 다양한`** `방법으로 코딩해보세요.`
#
#
#
# ```python
# x = ["grapes", "mango", "orange", "peach", "apple", "lime", "banana", "cherry", "tomato", "kiwi", "blueberry", "watermelon"]
#
# 출력 결과 : [APPLE, KIWI]
# ```

# %% [markdown]
# #### **`코딩영역`**

# %%
# 코딩 영역

# %% [markdown]
# #### **`Hint`**

# %% [markdown]
# <details>
#     <summary>▶<b>여기</b>를 눌러주세요</summary>
# <div markdown="1">
#
# ```python
# # 파이썬에서 사용가능한 반복문(for, while)은 기억하시죠? -> (break, continue) 필수 기억!
# # 시퀀스 자료형(데이터의 값이 연속적으로 이루어진 자료구조) : List, Tuple, Str, Range..
# # filter(f, iterable) 함수는 정말 많이 사용해요.(map 함수도 중요!)
# # lambda expression(형식)은 다른 함수의 인수 전달 형태로 사용해요.
# ```
# </div>
# </details>

# %% [markdown]
# ***

# %% [markdown]
# #### **`결과 & 보충설명`**

# %%
x = ["grapes", "mango", "orange", "peach", "apple", "lime", "banana", "cherry", "tomato", "kiwi", "blueberry", "watermelon"]


# 방법 1
ex1 = []
for i in range(len(x)):        # x의 길이만큼 만복
    if x[i] == 'apple' or x[i] == 'kiwi':     # x가 'apple'이거나 'kiwi'일때만 참 ->아래 코드 실행 
        ex1.append(x[i].upper())       # 조건이 맞다면 .upper() 대문자로 변환하여 더하기 

print(f'ex1 결과 : {ex1}')


# 방법 2
ex2 = filter(lambda a: a == 'apple' or a == 'kiwi',x)    # lambda a: a == 'apple' or a == 'kiwi' => 각 요소가 apple 이나 kiwi 인지 확인
print(list(ex2))

ex22 = list(map(lambda b: b.upper(), filter(lambda a: a == 'apple' or a == 'kiwi',x)))  # map(lambda b: b.upper()) => 각 요소에 대해 대문자로 변환
print(list(ex22))                                                                 # map 함수 : filter로 나온 결과에 대해 주어진 함수 적용

print(f'ex22 결과 : {ex1}')


# 방법 3
ex3 = [a.upper() for a in x if a =='apple' or a== 'kiwi']
print(f'ex3 결과 : {ex3}')
# Out:
# ex1 결과 : ['APPLE', 'KIWI']
# ['apple', 'kiwi']
# ['APPLE', 'KIWI']
# ex22 결과 : ['APPLE', 'KIWI']
# ex3 결과 : ['APPLE', 'KIWI']
